# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
df = pd.read_csv('/home/shikhar/Downloads/Datasets_interns/Ex07_Sonar_Regreesion.csv')
df
# Out:
#     EchoTime  WaterTemp  Clconcentration   Salinity        pH     Distance
# 0   3.910316          3        19.013137  34.348183  8.042168  2443.947414
# 1   5.526889          5        19.017350  34.355793  7.956494  3454.305721
# 2   3.519366          6        19.004284  34.332190  8.020561  2199.604042
# 3   3.724732          6        18.989512  34.305502  7.843142  2327.957553
# 4   4.924487          4        19.015003  34.351554  7.998218  3077.804222
# 5   6.467487          6        19.001236  34.326682  8.010355  4042.179288
# 6   3.448147          4        18.996399  34.317944  7.916522  2155.091890
# 7   6.419595          7        18.988974  34.304530  7.880541  4012.246683
# 8   2.883500          9        18.989140  34.304831  7.927781  1802.187572
# 9   6.805266          5        18.990197  34.306740  8.000301  4253.290984
# 10  2.346363          8        18.991149  34.308460  7.965927  1466.477024
# ...

# %%
#Target variable
y = df['Distance'].values

#Predictors
mean_pH = np.mean(df['pH'])
df['pH'].replace(np.nan, mean_pH, inplace = True)
X = df.iloc[:, 0:-1]
X = df.drop('Distance', axis = 1).values
print("After removing NaN from pH: ")
print(X)
# Out:
# After removing NaN from pH:
# [[  3.91031586   3.          19.01313731  34.34818321   8.04216838]
#  [  5.52688915   5.          19.01734977  34.35579323   7.95649445]
#  [  3.51936647   6.          19.00428438  34.33218994   8.02056076]
#  [  3.72473209   6.          18.98951164  34.30550226   7.84314177]
#  [  4.92448676   4.          19.01500291  34.35155351   7.99821808]
#  [  6.46748686   6.          19.00123576  34.32668245   8.01035477]
#  [  3.44814702   4.          18.99639889  34.31794441   7.91652179]
#  [  6.41959469   7.          18.9889737   34.30453043   7.88054081]
#  [  2.88350012   9.          18.98913988  34.30483065   7.92778075]
#  [  6.80526557   5.          18.99019706  34.30674049   8.00030132]
#  [  2.34636324   8.          18.99114889  34.30846003   7.96592711]
#  [  4.81266931  11.          19.0197201   34.36007534   8.03419917]
#  [  2.26540281   6.          19.01721752  34.3555543    7.96267702]
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 10)

# %%
regression = sklearn.linear_model.LinearRegression()

model = regression.fit(X_train, y_train)

# %%
prediction = model.predict(X_test)
print(prediction)
# Out:
# [ 3635.28620649  3151.73575187  4495.69798218  2569.48984494  5395.94190609
#   2327.95755341  4133.01756174  2815.15737985  4047.66020397  3908.05392118
#   2199.60404219  3454.30572109  3570.95630697  4207.91857013  1332.37334943
#   3995.12279437  2061.2856477   3850.68825556  3029.45207502  2452.54271991
#   2167.7400222   3955.22266787  3193.93853774  1968.35966708  3873.28905857
#   3613.97782938  3641.05961889  2158.3112424   2155.09188972  1605.53463589]

# %%
print("Model Intercept: ")
print(model.intercept_)

print("Model Coefficient")
print(model.coef_)
# Out:
# Model Intercept:
# -4.48835635325e-10
# Model Coefficient
# [  6.25000000e+02  -1.03865826e-13   3.15364236e+00  -1.74567123e+00
#    7.75723678e-13]

# %%
regression.score(X_test, y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, prediction))
print("Root Mean Squared Error: {}".format(rmse))
# Out:
# Root Mean Squared Error: 3.020163827731858e-12

# %%
print(r2_score(y_test, prediction))
# Out:
# 1.0

# %%
correlation=df.corr()["Distance"][:-1]
print(correlation)
# Out:
# EchoTime           1.000000
# WaterTemp         -0.046306
# Clconcentration   -0.074808
# Salinity          -0.074808
# pH                 0.097267
# Name: Distance, dtype: float64

# %%
#By the intuition of correraltion score we can get an idea of which feature is redundant and which needs to be considered
#Therefore we can try different versions of the model by seeing the correlation score of the features with the target 
#variable

# %%
#It can be seen from the correlation score that EchoTime is highly correlated with the Distance.
